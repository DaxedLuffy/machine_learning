# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
modenum = stats.mode(speed) #value that appears most number of times
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
meannum = np.mean(speed)
mediannum = np.median(speed)#the value in the middle after we have sorted all values
stddev = np.std(speed) #how spread out the values are sigma
variance = np.var(speed) #how spread out values are sigma*sigma
#stddev = var*var
# Out:
# /tmp/ipykernel_19344/4099651497.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   modenum = stats.mode(speed) #value that appears most number of times

# %%
meannum
mediannum
# Out:
# 87.0

# %%
stddev
# Out:
# 9.258292301032677

# %%
#Percentiles are used in statistics to give you a number that describes the value that a given percent of the values are lower than.
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31] 
# What is the 75. percentile? The answer is 43, meaning that 75% of the people are 43 or younger.
percentilenum = np.percentile(ages, 75)
percentilenum
# Out:
# 80.8

# %%
#calculating percentile 1-100 eg np.percenrtile(ages, 95) = 80.0 meaning 95% of ppl are 80 or younger 
for i in range(1,100):
    percentilenum = np.percentile(ages, i)
    print(i, percentilenum, percentilenum in ages)
# Out:
# 1 2.6 False
# 2 3.2 False
# 3 3.8 False
# 4 4.4 False
# 5 5.0 True
# 6 5.2 False
# 7 5.4 False
# 8 5.6 False
# 9 5.8 False
# 10 6.0 True
# 11 6.2 False
# 12 6.4 False
# 13 6.6 False
# 14 6.800000000000001 False
# 15 7.0 True
# 16 7.2 False
# 17 7.4 False
# 18 7.6 False
# 19 7.8 False
# 20 8.0 True
# 21 8.600000000000001 False
# 22 9.200000000000001 False
# 23 9.8 False
# 24 10.399999999999999 False
# 25 11.0 True
# 26 11.8 False
# 27 12.600000000000001 False
# 28 13.400000000000002 False
# 29 14.2 False
# 30 15.0 True
# 31 17.0 False
# 32 19.000000000000004 False
# 33 21.000000000000007 False
# 34 23.000000000000007 False
# 35 25.0 True
# 36 25.4 False
# 37 25.8 False
# 38 26.2 False
# 39 26.6 False
# 40 27.0 True
# 41 27.799999999999997 False
# 42 28.6 False
# 43 29.4 False
# 44 30.200000000000003 False
# 45 31.0 True
# 46 31.0 True
# 47 31.0 True
# 48 31.0 True
# 49 31.0 True
# 50 31.0 True
# 51 31.2 False
# 52 31.4 False
# 53 31.6 False
# 54 31.8 False
# 55 32.0 True
# ...

# %%
# array containing 250 random floats between 0 and 5
randnum = np.random.uniform(0.0,5.0,250)
randnum
# Out:
# array([6.81192786e-01, 1.55926418e+00, 6.32898571e-01, 1.25072681e-01,
#        2.66957360e+00, 2.59128957e+00, 1.38150507e+00, 2.11420724e+00,
#        3.57026057e+00, 4.56015101e+00, 4.40898850e+00, 3.60607841e+00,
#        1.70767857e+00, 5.35616730e-01, 4.38567850e+00, 4.18824897e+00,
#        1.43253479e+00, 4.22789728e+00, 1.50997221e+00, 3.44980291e+00,
#        2.60726210e+00, 4.52073782e+00, 5.33364298e-01, 4.00600299e+00,
#        2.09600429e+00, 4.50056261e+00, 5.44969868e-01, 3.49621434e+00,
#        7.49660575e-01, 4.58498716e+00, 1.62265103e-01, 7.36249188e-03,
#        4.28276770e-01, 3.13369611e+00, 6.93787932e-01, 1.70749044e+00,
#        2.47496159e+00, 3.13002723e+00, 2.44230558e+00, 3.25339855e+00,
#        4.42403263e+00, 8.38395720e-01, 1.23264209e+00, 1.22521955e-01,
#        2.80671918e+00, 6.74451307e-01, 2.00092452e+00, 3.68434846e+00,
#        1.58474485e-02, 2.55904052e+00, 1.88978097e+00, 2.59035109e+00,
# ...

# %%
#using histogram to plot data
plt.hist(randnum, 5)
plt.show()

# %%
randdum = np.random.uniform(0.0,5.0,100000)
plt.hist(randdum, 100)
# Out:
# (array([1020.,  979.,  972., 1022., 1017.,  955.,  989.,  993.,  978.,
#         1008., 1037., 1033., 1017.,  980.,  966.,  980., 1021., 1041.,
#          980., 1013.,  964., 1009.,  995.,  988.,  933., 1019., 1017.,
#         1014.,  996.,  976., 1013., 1046.,  912.,  991.,  999.,  996.,
#         1074., 1035.,  961.,  987., 1003., 1001., 1000.,  986.,  980.,
#          992.,  984.,  977., 1035., 1051., 1006., 1041.,  952., 1022.,
#          948.,  993., 1001., 1055.,  988.,  969., 1008.,  995., 1013.,
#         1018.,  986.,  985.,  996.,  986.,  986.,  992., 1089.,  957.,
#         1013., 1033.,  985., 1033., 1042., 1004.,  975., 1032., 1043.,
#         1049.,  976.,  937.,  964., 1020., 1044.,  958.,  998., 1002.,
#         1005.,  936.,  964.,  992., 1033., 1014., 1007., 1004., 1006.,
#         1010.]),
#  array([3.75420771e-05, 5.00371326e-02, 1.00036723e-01, 1.50036314e-01,
#         2.00035904e-01, 2.50035495e-01, 3.00035085e-01, 3.50034676e-01,
# ...

# %%
# mean value is 5.0, and the standard deviation is 1.0
normalnum = np.random.normal(5.0,1.0,100000)
plt.hist(normalnum, 100)
plt.show()

# %%
#x-axis represents ages, and the y-axis represents speeds of cars
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
#two fastest cars were both 2 years old, and the slowest car was 12 years old

# %%
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)

# %%
'''
Linear regression uses the relationship between the data-points to draw a straight line through all them.

This line can be used to predict future values.

'''

car_age = [5,7,8,7,2,17,2,9,4,11,12,9,6]
car_speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(car_age, car_speed)

# %%
slope, intercept, r, p, std_err = stats.linregress(car_age, car_speed)


def myfunc(x):
    return slope*x + intercept

# %%
mymodel = list(map(myfunc, car_age))

# %%
plt.scatter(car_age, car_speed)
plt.plot(car_age, mymodel)
plt.show()
#as the car age increases car speed decreases

# %%
'''
It is important to know how the relationship between the values of the x-axis and the values of the y-axis is, 

if there are no relationship the linear regression can not be used to predict anything. This relationship - the coefficient of correlation - is called r. 

The r value ranges from -1 to 1, where 0 means no relationship, and 1 (and -1) means 100% related.

slope, intercept, r, p, std_err = stats.linregress(car_age, car_speed)

'''

print(r)
# Out:
# -0.758591524376155

# %%
#predict future values done through myfunc eg speed of car 10 yrs old is :
speed10 = myfunc(10)
speed10
# Out:
# 85.59308314937454

# %%
#BADFIT for linear regression => r -> 0

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x,y)

print(r)
# Out:
# 0.01331814154297491

# %%
#POLYNOMIAL REGRESSION

houroftheday = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
car_speed = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(houroftheday, car_speed)

# %%
mymodel = np.poly1d(np.polyfit(houroftheday, car_speed, 3)) #NumPy has a method that lets us make a polynomial model, 3 is degree of fitting polynomail
myline = np.linspace(1, 22, 100) #Then specify how the line will display, we start at position 1, and end at position 22:
plt.scatter(houroftheday, car_speed) #Draw the original scatter plot
plt.plot(myline, mymodel(myline)) #Draw the line of polynomial regression
plt.show()

# %%
# The relationship is measured with a value called the r-squared.

# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related.

from sklearn.metrics import r2_score
print(r2_score(car_speed, mymodel(houroftheday)))
# Out:
# 0.9432150416451027

# %%
#Predict the speed of a car passing at 17:00
speed = mymodel(17)
speed
# Out:
# 88.87331269697987

# %%
#BADFIT for polynomial regression
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]
mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652
